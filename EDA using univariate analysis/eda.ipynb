# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("tips.csv")

# %%
# -----------------------------
# Basic Information
# -----------------------------
print("Shape:")
print(df.shape)

print("\nInformation:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Shape:
# (50, 7)
#
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  50 non-null     float64
#  1   tip         50 non-null     float64
#  2   sex         50 non-null     str
#  3   smoker      50 non-null     str
#  4   day         50 non-null     str
#  5   time        50 non-null     str
#  6   size        50 non-null     int64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 2.9 KB
# None
#
# Summary Statistics:
#        total_bill        tip       size
# count   50.000000  50.000000  50.000000
# mean    29.141200   4.090600   2.860000
# std     68.475988   6.826092   1.160753
# min      8.350000   1.010000   2.000000
# 25%     14.882500   2.000000   2.000000
# 50%     17.795000   3.000000   2.000000
# 75%     21.670000   3.607500   3.750000
# max    500.000000  50.000000   6.000000

# %%
# -----------------------------
# Missing Values
# -----------------------------
print("\nMissing Values:")
print(df.isnull().sum())

# %%
# -----------------------------
# Unique Values
# -----------------------------
print("\nUnique Days:")
print(df["day"].unique())

print("\nGender Counts:")
print(df["sex"].value_counts())

# %%
# -----------------------------
# Numerical Column Analysis
# -----------------------------
print("\nSkewness of Total Bill:")
print(df["total_bill"].skew())

# %%
# -----------------------------
# Histogram
# -----------------------------
plt.figure(figsize=(6,4))
sns.histplot(df["total_bill"], kde=True)
plt.title("Distribution of Total Bill")
plt.show()

# %%
# -----------------------------
# Box Plot
# -----------------------------
plt.figure(figsize=(6,4))
sns.boxplot(x=df["total_bill"])
plt.title("Box Plot of Total Bill")
plt.show()

# %%
# -----------------------------
# Count Plot
# -----------------------------
plt.figure(figsize=(6,4))
sns.countplot(x=df["sex"])
plt.title("Gender Count")
plt.show()

# %%
# -----------------------------
# Pie Chart
# -----------------------------
df["sex"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()
